# %% [markdown]
# ## Vacuum Gauge Explorer
# Interactive tool for stepping through different gauges across many fills. Features include:
# * Single key-press navigation
#     * Step Forward / Backward
#     * Jump to Specific Fill
#     * Save favourite location(s)
#     * Automatic step through X fills with pre-specified location
# * On-the-fly use of loaded classifiers
#     * Load models of choice
#     * Visualize analytical approaches
# * Multi-plotting of gauges
# * Automatic saving of loaded figures and data (quicker access in subsequent runs)

# %% [markdown]
# ## Setup Environment
# **Warning**: May be slow as the explorer loads in many functions

# %%
# %run BackEnd_Vacuum_Gauge_Explorer.ipynb
# Out:
# Valid Fill Numbers: 0 - 7494 (inclusive)
# Please select a fill number >>>5979
# Possible locations:
# array(['12L1', '12L2', '12L3', '12L4', '12L5', '12L6', '12L7', '12L8',
#        '12R1', '12R2', '12R3', '12R4', '12R5', '12R6', '12R7', '12R8',
#        '13L1', '13L2', '13L3', '13L4', '13L5', '13L6', '13L7', '13L8',
#        '13R1', '13R2', '13R3', '13R4', '13R5', '13R6', '13R7', '13R8',
#        '1L1', '1L2', '1L5', '1L8', '1R1', '1R2', '1R5', '1R8', '4L1',
#        '4L2', '4L3', '4L5', '4L6', '4L7', '4L8', '4R1', '4R2', '4R5',
#        '4R6', '4R7', '4R8', '5L1', '5L2', '5L3', '5L4', '5L5', '5L6',
#        '5L7', '5L8', '5R1', '5R2', '5R3', '5R4', '5R5', '5R6', '5R7',
#        '5R8', '6L1', '6L2', '6L3', '6L4', '6L5', '6L7', '6L8', '6R1',
#        '6R2', '6R3', '6R4', '6R5', '6R7', '6R8', '7L1', '7L2', '7L3',
#        '7L4', '7L5', '7L7', '7L8', '7R1', '7R2', '7R3', '7R4', '7R5',
#        '7R7', '7R8'], dtype='<U4')
# Select a segment by number. Example: 3L17
# ...

# %%
controller = VGcontrol(verbose=False)
