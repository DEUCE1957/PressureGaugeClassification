# %%
# %run ./Vacuum_Gauge_Class.ipynb
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/swan/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['fill']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
fill = 2953#2011
vg = VacuumGauge(fill,beamNumber=1)
# Out:
# ...
# Beam intensity succesfully downloaded
# ...
# Beam energy succesfully downloaded
# ...
# Beam bunch lengths succesfully downloaded

# %%
gauge_id = 'VGPB.520.4R6.B.PR'
vg.getData(gauge_id)

# acronyms = {"VGA":"Vacuum Gauge Analyser", X
#            "VGF":"Vacuum Gauge Combined Pirai/Penning", X
#            "VGH":"Vacuum Gauge Combined Pirai/Bayard-Alpert", X
#            "VGI":"Vacuum Gauge Hot Cathode", X
#            "VGM":"Vacuum Gauge Membrane", X (chaotic)
#            "VGP":"Vacuum Gauge Penning",
#            "VGR":"Vacuum Gauge Pirani"}  X (some cut off)
# Out:
# ...
# Vacuum gauge data succesfully downloaded

# %% [markdown]
# # Remove empty readings:

# %%
count = 0
for col in vg.data.columns:
    if len(vg.data.loc['timeStamp'][col]) == 0:
        vg.data.drop(col, inplace=True, axis=1)
        count += 1
print('Empty readings removed: %d' %count)
#         print np.max(vg.data.loc['timeStamp'][col])

# %%
vg.plot()
#vg.sliced_plot(slice_number=10)
# Out:
# <img src="data:image/png;base64,..." width="999.35">

# %%
# %run Vacuum_Gauge_Class_Suite.ipynb

# %%
f, ax, coupled = analytical_classifier(gauge_id,fill)

# %%
print(coupled)
